# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('heart-deasease.csv')

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 0)

scaling_ = StandardScaler()
x_train  = scaling_.fit_transform(x_train)
x_test  = scaling_.transform(x_test)

# %%
x_train
# Out:
# array([[-1.32773282, -1.43641607,  0.98584243, ..., -0.66169316,
#         -0.70710678, -0.46472917],
#        [ 1.24903178, -1.43641607,  0.98584243, ..., -0.66169316,
#          0.26516504, -0.46472917],
#        [ 0.35276583,  0.69617712,  0.98584243, ...,  0.95577901,
#         -0.70710678, -0.46472917],
#        ...,
#        [ 0.12869935,  0.69617712,  1.94013791, ..., -0.66169316,
#         -0.70710678,  1.14190596],
#        [-0.87959984,  0.69617712,  0.98584243, ...,  0.95577901,
#         -0.70710678, -0.46472917],
#        [ 0.35276583,  0.69617712,  0.03154696, ..., -0.66169316,
#         -0.70710678, -0.46472917]])

# %%
classifier = Sequential()
classifier.add(Dense(units=7,activation = 'relu',kernel_initializer='uniform',input_dim=13))
classifier.add(Dense(units=7,activation = 'relu',kernel_initializer='uniform'))
classifier.add(Dense(units=1,activation = 'sigmoid',kernel_initializer='uniform'))

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics = ['accuracy'])

# %%
classifier.fit(x_train,y_train,batch_size=10,epochs=150)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 0s 795us/step - loss: 0.6932 - accuracy: 0.4793
# Epoch 2/150
# 25/25 [==============================] - 0s 842us/step - loss: 0.6924 - accuracy: 0.5744
# Epoch 3/150
# 25/25 [==============================] - 0s 607us/step - loss: 0.6898 - accuracy: 0.7355
# Epoch 4/150
# 25/25 [==============================] - 0s 804us/step - loss: 0.6813 - accuracy: 0.8264
# Epoch 5/150
# 25/25 [==============================] - 0s 750us/step - loss: 0.6603 - accuracy: 0.8471
# Epoch 6/150
# 25/25 [==============================] - 0s 708us/step - loss: 0.6254 - accuracy: 0.8430
# Epoch 7/150
# 25/25 [==============================] - 0s 792us/step - loss: 0.5838 - accuracy: 0.8264
# Epoch 8/150
# 25/25 [==============================] - 0s 958us/step - loss: 0.5503 - accuracy: 0.8347
# Epoch 9/150
# 25/25 [==============================] - 0s 708us/step - loss: 0.5274 - accuracy: 0.8512
# Epoch 10/150
# ...

# %%
y_predict = classifier.predict(x_test)
print("accuracy is using ANN= ",accuracy_score(y_predict>0.5,y_test))
# Out:
# accuracy is using ANN=  0.9016393442622951

# %%
lr = RandomForestClassifier()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.8524590163934426

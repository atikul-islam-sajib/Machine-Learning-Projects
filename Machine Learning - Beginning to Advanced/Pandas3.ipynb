# %% [markdown]
# # Read the First DataSet

# %%
#Import all import built-in Function
from functools import reduce
from collections import Counter
from itertools import permutations, combinations, chain
import pandas as pd
import numpy as np
import string
import ast

# %%
#read the first DataFrame
df1_ = pd.read_csv('tmdb_5000_movies.csv')
#print the dataFrame
df1_.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#Chech the shape of this dataset:
print("the shape of this dataset is: ", df1_.shape, '\n')
#Check there is any null value or not presence
columnName_ = df1_.columns[df1_.isnull().sum()>0]
nullValue_  = df1_.isnull().sum()[df1_.isnull().sum().values>0].values

for columnName_, nullValue_ in zip(columnName_, nullValue_):
    print(f'{columnName_:{12}}  - {nullValue_:{10}}')
# Out:
# the shape of this dataset is:  (4803, 20)
#
# homepage      -       3091
# overview      -          3
# release_date  -          1
# runtime       -          2
# tagline       -        844

# %%
#Now create of dataFrame of using null value:
columnName_ = df1_.columns[df1_.isnull().sum()>0]
dict_ = {}

for values_ in columnName_:
    dict_[values_] = df1_.loc[:, values_].values
    print(f"{values_:{12}} completed:",'\n')
    
print("Fully completed: ")
# Out:
# homepage     completed:
#
# overview     completed:
#
# release_date completed:
#
# runtime      completed:
#
# tagline      completed:
#
# Fully completed:

# %%
#Print the dictonary
for keys_, values_ in dict_.items():
    print(keys_, values_)
# Out:
# homepage ['http://www.avatarmovie.com/'
#  'http://disney.go.com/disneypictures/pirates/'
#  'http://www.sonypictures.com/movies/spectre/' ...
#  'http://www.hallmarkchannel.com/signedsealeddelivered'
#  'http://shanghaicalling.com/' nan]
# overview ['In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'
#  'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.'
#  'A cryptic message from Bond’s past sends him on a trail to uncover a sinister organization. While M battles political forces to keep the secret service alive, Bond peels back the layers of deceit to reveal the terrible truth behind SPECTRE.'
#  ...
# ...

# %%
#Create a dataFrame with that dict_
nullDataFrame_ = pd.DataFrame(dict_)
nullDataFrame_.head()
# Out:
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10    162.0
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19    169.0
# 2  A cryptic message from Bond’s past sends him o...   2015-10-26    148.0
# 3  Following the death of District Attorney Harve...   2012-07-16    165.0
# 4  John Carter is a war-weary, former military ca...   2012-03-07    132.0
#
#                                           tagline
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# ...

# %%
#print the shape and check the null value is presence or not
print("the shape of this dataframe is: ", nullDataFrame_.shape,'\n')
length_ = len(nullDataFrame_.isnull().sum())

for i in range(length_):
    columns_ = nullDataFrame_.isnull().sum().index[i]
    values_  = nullDataFrame_.isnull().sum().values[i]
    print(f'{columns_:{12}} has total null values {values_:{10}}')
# Out:
# the shape of this dataframe is:  (4803, 5)
#
# homepage     has total null values       3091
# overview     has total null values          3
# release_date has total null values          1
# runtime      has total null values          2
# tagline      has total null values        844

# %%
#I want to print all the datatypes of columns:
for columns_, dtypes_ in zip(df1_.dtypes.index, df1_.dtypes.values):
    print(f"{columns_:{40}}  {dtypes_}")
# Out:
# budget                                    int64
# genres                                    object
# homepage                                  object
# id                                        int64
# keywords                                  object
# original_language                         object
# original_title                            object
# overview                                  object
# popularity                                float64
# production_companies                      object
# production_countries                      object
# release_date                              object
# revenue                                   int64
# runtime                                   float64
# spoken_languages                          object
# status                                    object
# tagline                                   object
# title                                     object
# vote_average                              float64
# ...

# %%
#I want to chceck the unique datatypes:
uniqueDataTypes_ = df1_.dtypes.unique()
for values_ in uniqueDataTypes_:
    print(values_,'\n')
print("the number of unique data types is: ", df1_.dtypes.nunique())
# Out:
# int64
#
# object
#
# float64
#
# the number of unique data types is:  3

# %%
#split the dataset with that dtypes
categoricalDataSet_ = df1_.select_dtypes(include = ['object'])
numericDataSet_     = df1_.select_dtypes(exclude = ['object'])

# %%
#print the categorical data 
categoricalDataSet_.head(4)
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
#print the numerical_data
numericDataSet_.head(4)
# Out:
#       budget      id  popularity     revenue  runtime  vote_average  \
# 0  237000000   19995  150.437577  2787965087    162.0           7.2
# 1  300000000     285  139.082615   961000000    169.0           6.9
# 2  245000000  206647  107.376788   880674609    148.0           6.3
# 3  250000000   49026  112.312950  1084939099    165.0           7.6
#
#    vote_count
# 0       11800
# 1        4500
# 2        4466
# 3        9106

# %% [markdown]
# # Read the Second DataSet

# %%
df2_ = pd.read_csv('tmdb_5000_credits.csv')
df2_.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
#print the shape of this dataset
print("The shape of this dataset is  : ", df2_.shape,'\n')
print("The number of rows in here    :", df2_.shape[0],'\n')
print("The number of columns in here :", df2_.shape[1],'\n')
# Out:
# The shape of this dataset is  :  (4803, 4)
#
# The number of rows in here    : 4803
#
# The number of columns in here : 4

# %%
#Check two dataset's rows are equal or not:
check_ = df1_.shape[0] == df2_.shape[0]
if check_ == True:
    print("The dataset is SAME, taking their row numbers into account")
else:
    print("The dataset isn't SAME, taking their row numbers into account")
# Out:
# The dataset is SAME, taking their row numbers into account

# %%
#Find Null value is available or not
columns_ = df2_.isnull().sum().index
values_  = df2_.isnull().sum().values

for columns_, values_ in zip(columns_, values_):
    print(f"{columns_:{10}} {values_}")
# Out:
# movie_id   0
# title      0
# cast       0
# crew       0

# %%
#Find the data types of this dataFrame
columns_ = df2_.dtypes.index
dtypes_  = df2_.dtypes.values

for columns_, dtypes_ in zip(columns_, dtypes_):
    print(f"{columns_:{10}} {dtypes_}")
# Out:
# movie_id   int64
# title      object
# cast       object
# crew       object

# %%
#Now print the df1_ and df2_ columns name

for columns_ in df1_.columns:
    print("Column name is: ",columns_)
    
print("     ")

for columns_ in df2_.columns:
    print("Column name is: ", columns_)
# Out:
# Column name is:  budget
# Column name is:  genres
# Column name is:  homepage
# Column name is:  id
# Column name is:  keywords
# Column name is:  original_language
# Column name is:  original_title
# Column name is:  overview
# Column name is:  popularity
# Column name is:  production_companies
# Column name is:  production_countries
# Column name is:  release_date
# Column name is:  revenue
# Column name is:  runtime
# Column name is:  spoken_languages
# Column name is:  status
# Column name is:  tagline
# Column name is:  title
# Column name is:  vote_average
# Column name is:  vote_count
#
# Column name is:  movie_id
# Column name is:  title
# Column name is:  cast
# Column name is:  crew

# %%
#Now, what i will have to check two ID
fistMovieId_   = df1_.loc[:, 'id']
secondMovieId_ = df2_.loc[:, 'movie_id']
#check two ID is same or not 
check_ = fistMovieId_ == secondMovieId_
if check_.all() == True:
    print(True, ": ID's are SAME")
else:
    print(False, ": ID's NOT same")
# Out:
# True : ID's are SAME

# %%
#Now set the "id" as a index of df1_
df1_.set_index('id', inplace = True)
#now print the df1_
df1_.head(4)
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                             homepage  \
# id
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# ...

# %%
#But i want to delete the "id" index name
df1_.index.name = None
#print the df1_
df1_.head(5)
# Out:
#            budget                                             genres  \
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  \
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
# 49529           http://movies.disney.com/john-carter
#
#                                                  keywords original_language  \
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
#The same process will be done by df2_
df2_.set_index('movie_id', inplace = True)
#Now, delete the name of index
df2_.index.name = None
#print the df2_
df2_.head(5)
# Out:
#                                            title  \
# 19995                                     Avatar
# 285     Pirates of the Caribbean: At World's End
# 206647                                   Spectre
# 49026                      The Dark Knight Rises
# 49529                                John Carter
#
#                                                      cast  \
# 19995   [{"cast_id": 242, "character": "Jake Sully", "...
# 285     [{"cast_id": 4, "character": "Captain Jack Spa...
# 206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 49026   [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 49529   [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                      crew
# 19995   [{"credit_id": "52fe48009251416c750aca23", "de...
# 285     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 206647  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 49026   [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
#I want to check the columns name are same or not in both data Frame

firstDataSetColumnsName_  = df1_.columns
secondDataSetColumnsName_ = df2_.columns

flag_       = -1
columnName_ = ""
for columnsName1_ in firstDataSetColumnsName_:
    for columnsName2_ in secondDataSetColumnsName_:
        if columnsName1_ == columnsName2_:
            flag_ = 0
            columnName_ = columnsName1_
            break
        else:
            flag_ = 1

if flag_ == 0:
    print("The columns name are NOT same: ")
else:
    print("The columns name is SAME, and the name of columns is: ",columnName_)
# Out:
# The columns name is SAME, and the name of columns is:  title

# %%
#NoW What i will have to check "title" columns has the same value in both dataFrame or not
firstDataSetTitle_  = df1_.loc[:, 'title']
secondDataSetTitle_ = df2_.loc[:, 'title']

check_ = firstDataSetTitle_ == secondDataSetTitle_

if check_.all() == True:
    print("Yes, the values are SAME")
else:
    print("No, the values are NOT same")
# Out:
# Yes, the values are SAME

# %%
#Now Delete the "title" columns from the "df2_ or df1_"
df2_.drop('title', axis = 1, inplace = True)
print("Dropped !")
# Out:
# Dropped !

# %%
#Now, check the column is really dropped or not
print("the shape of the data set is : ", df2_.shape,'\n')
df2_.head()
# Out:
# the shape of the data set is :  (4803, 2)
#                                                      cast  \
# 19995   [{"cast_id": 242, "character": "Jake Sully", "...
# 285     [{"cast_id": 4, "character": "Captain Jack Spa...
# 206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 49026   [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 49529   [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                      crew
# 19995   [{"credit_id": "52fe48009251416c750aca23", "de...
# 285     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 206647  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 49026   [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 49529   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#Now, print the shape of the "df1_","df2_"
print("The shape of the df1_ is: ", df1_.shape,'\n')
print("The shape of the df2_ is: ", df2_.shape, '\n')
# Out:
# The shape of the df1_ is:  (4803, 19)
#
# The shape of the df2_ is:  (4803, 2)

# %% [markdown]
# # Concatenate the DataFrames

# %%
#Now, "concatenate" the "df1_" and "df2_"
df_ = pd.concat([df1_, df2_], axis = 1)
print("Done !")
# Out:
# Done !

# %%
#print the new "df_"
df_.head(5)
# Out:
#            budget                                             genres  \
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  \
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
# 49529           http://movies.disney.com/john-carter
#
#                                                  keywords original_language  \
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
#Now, print the shape and analysis

print("the shape of the df1_ was        : ".capitalize(), df1_.shape,'\n')
print("the shape of the df2_ was        : ".capitalize(), df2_.shape,'\n')

newColumnsCount_ = df1_.shape[1] + df2_.shape[1]

print("the number of new columns will be: ".capitalize(), newColumnsCount_,'\n')
print("the new df_ shape is been        : ".capitalize(), df_.shape,'\n')

#check the columns are same or not
if df_.shape[1] == newColumnsCount_:
    print("The number of columns are same: ", newColumnsCount_)
else:
    print("The number of columns are not same: ". newColumnsCount_)
# Out:
# The shape of the df1_ was        :  (4803, 19)
#
# The shape of the df2_ was        :  (4803, 2)
#
# The number of new columns will be:  21
#
# The new df_ shape is been        :  (4803, 21)
#
# The number of columns are same:  21

# %%
for columns_ in df_.columns:
    print(columns_)
# Out:
# budget
# genres
# homepage
# keywords
# original_language
# original_title
# overview
# popularity
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# vote_average
# vote_count
# cast
# crew

# %%
#We will delete some columns, which are not necessary: the name of dropped column is given below:
#1.budget 2.homepage 3.keywords 4.original_language 5. popularity 6. production_companies 7.production_countries 8. release_date
#9.runtime 10.spoken_languages 11.status 12.vote_average 13. vote_count 

dropList_ = ["budget","homepage","original_title","popularity","production_companies","production_countries","release_date",
            "revenue","runtime","spoken_languages","tagline","vote_average","vote_count","original_language","status"]

useColumns_ = []

for columns_ in df_.columns:
    if columns_ in dropList_:
        print(columns_, "will not be taken for futher operation:\n")
    else:
        useColumns_.append(columns_)
        
print("Completed....")
print("the use columnns_ are: ", useColumns_)
# Out:
# budget will not be taken for futher operation:
#
# homepage will not be taken for futher operation:
#
# original_language will not be taken for futher operation:
#
# original_title will not be taken for futher operation:
#
# popularity will not be taken for futher operation:
#
# production_companies will not be taken for futher operation:
#
# production_countries will not be taken for futher operation:
#
# release_date will not be taken for futher operation:
#
# revenue will not be taken for futher operation:
#
# runtime will not be taken for futher operation:
#
# spoken_languages will not be taken for futher operation:
#
# status will not be taken for futher operation:
#
# tagline will not be taken for futher operation:
#
# vote_average will not be taken for futher operation:
#
# vote_count will not be taken for futher operation:
#
# Completed....
# the use columnns_ are:  ['genres', 'keywords', 'overview', 'title', 'cast', 'crew']

# %%
#Check_
print("Total number of columns were        : ", len(df_.columns),"\n")
print("Total number of dropped columns were: ", len(dropList_),"\n")
remainingColumns_ = len(df_.columns) - len(dropList_)
print("The remaining columns for operation : ", remainingColumns_,"\n")
print("The length of the use Columns are   : ", len(useColumns_))
# Out:
# Total number of columns were        :  21
#
# Total number of dropped columns were:  15
#
# The remaining columns for operation :  6
#
# The length of the use Columns are   :  6

# %%
#Now Create a dataFrame using that "useColumns_"
df_ = df_.loc[:, useColumns_]
print("Done ! ")
# Out:
# Done !

# %%
#print the new df_ using that certain "useColumns_"
#print the shape first
print("the shape of df_ using useColumns_ is     : ".capitalize(), df_.shape,'\n')
print("the number of nows are presence in here   : ".capitalize(), df_.shape[0],'\n')
print("the number of columns are presence in here: ".capitalize(), df_.shape[1],'\n')
df_.head(3)
# Out:
# The shape of df_ using usecolumns_ is     :  (4803, 6)
#
# The number of nows are presence in here   :  4803
#
# The number of columns are presence in here:  6
#                                                    genres  \
# 19995   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                  keywords  \
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                                                  overview  \
# 19995   In the 22nd century, a paraplegic Marine is di...
# 285     Captain Barbossa, long believed to be dead, ha...
# 206647  A cryptic message from Bond’s past sends him o...
#
#                                            title  \
# ...

# %%
#Check null value is presence or not
columnsName_ = df_.isnull().sum().index
nullValue_   = df_.isnull().sum().values


for columnsName_, nullValue_ in zip(columnsName_, nullValue_):
    print(f"{columnsName_:{9}} {nullValue_:{12}}            {df_[columnsName_].dtypes}")
# Out:
# genres               0            object
# keywords             0            object
# overview             3            object
# title                0            object
# cast                 0            object
# crew                 0            object

# %%
#Now, i will have to do use "fillna()" to remove the the null values:
print("the number of unique overview is: ".capitalize() ,df_['overview'].nunique(),'\n')
#So, we will unable to use "most frequent values in here"
#In order to "fillna()" either we will have to use "Missing" or "np.random.choice(overview)"
#In that case, we will go to go "np.random.choice(overview)"

df_.fillna(np.random.choice(df_.loc[:, 'overview']), inplace = True)
print("Done with fillna")
# Out:
# The number of unique overview is:  4800
#
# Done with fillna

# %%
#Now, check whether the "fillna()" worked perfectly or not
columnsName_ = df_.isnull().sum().index
nullValue_   = df_.isnull().sum().values

for columnsName_, nullValue_ in zip(columnsName_, nullValue_):
    print(f"{columnsName_:{9}} {nullValue_:{12}}")
# Out:
# genres               0
# keywords             0
# overview             0
# title                0
# cast                 0
# crew                 0

# %%
#Check again using "all()"
nullValue_   = df_.isnull().sum().values
check_ = nullValue_ == 0
if check_.all() == True:
    print("there is NO null value".capitalize())
else:
    print("there is NULL value".capitalize())
# Out:
# There is no null value

# %%
#Now, i will "reset_index()"
df_.reset_index(inplace = True)
print("Done !")
# Out:
# Done !

# %%
df_.head(3)
# Out:
#     index                                             genres  \
# 0   19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     285  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast  \
# ...

# %%
#First, have a overlook to "genres" columns_
print("the zero number index looks like in genres columns_ : \n", df_.loc[:, 'genres'][0],'\n')
#print the type of this rows
print("the type of this genres columns is: ",type(df_.loc[:, 'genres'][0]),'\n')
#So, it'a string type: now what i will have to do is convert to a list, by using "ast"
# Out:
# the zero number index looks like in genres columns_ :
#  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#
# the type of this genres columns is:  <class 'str'>

# %%
#Now, it converts into a list:
for values_ in df_.loc[:, 'genres']:
    values_ = ast.literal_eval(values_)
    print(type(values_))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ...

# %%
#Now, we will take just "name" from that dictonary and put into them that "genres" columns
genreList_ = []
for index_, values_ in enumerate(df_.loc[:, 'genres']):
    values_ = ast.literal_eval(values_)
    list_ = []
    for name_ in values_:
        list_.append(''.join(name_['name']))
    genreList_.append(list_)
    print("completed ", index_)
    
print(" ")
print("Fully completed !")
df_.loc[:, 'genres'] = genreList_
print("Completed")
# Out:
# completed  0
# completed  1
# completed  2
# completed  3
# completed  4
# completed  5
# completed  6
# completed  7
# completed  8
# completed  9
# completed  10
# completed  11
# completed  12
# completed  13
# completed  14
# completed  15
# completed  16
# completed  17
# completed  18
# completed  19
# completed  20
# completed  21
# completed  22
# completed  23
# completed  24
# completed  25
# completed  26
# completed  27
# completed  28
# completed  29
# completed  30
# completed  31
# completed  32
# completed  33
# completed  34
# completed  35
# completed  36
# completed  37
# completed  38
# completed  39
# completed  40
# completed  41
# completed  42
# completed  43
# completed  44
# completed  45
# completed  46
# completed  47
# completed  48
# completed  49
# completed  50
# completed  51
# completed  52
# completed  53
# completed  54
# completed  55
# completed  56
# completed  57
# completed  58
# completed  59
# completed  60
# completed  61
# completed  62
# ...

# %%
#now print the df_
df_.head()
# Out:
#     index                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#Now have a overlook into "keywords" columns_
df_.loc[:, 'keywords'][0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
#the same process which we have done a couple minutes ago
keywordsList_ = []
for index_, values_ in enumerate(df_.loc[:, 'keywords']):
    values_ = ast.literal_eval(values_)
    list_ = []
    for insideList_ in values_:
        list_.append(insideList_['name'])
    keywordsList_.append(list_)
    print(list_)
df_.loc[:, 'keywords'] = keywordsList_
print("Done !")
# Out:
# ['culture clash', 'future', 'space war', 'space colony', 'society', 'space travel', 'futuristic', 'romance', 'space', 'alien', 'tribe', 'alien planet', 'cgi', 'marine', 'soldier', 'battle', 'love affair', 'anti war', 'power relations', 'mind and soul', '3d']
# ['ocean', 'drug abuse', 'exotic island', 'east india trading company', "love of one's life", 'traitor', 'shipwreck', 'strong woman', 'ship', 'alliance', 'calypso', 'afterlife', 'fighter', 'pirate', 'swashbuckler', 'aftercreditsstinger']
# ['spy', 'based on novel', 'secret agent', 'sequel', 'mi6', 'british secret service', 'united kingdom']
# ['dc comics', 'crime fighter', 'terrorist', 'secret identity', 'burglar', 'hostage drama', 'time bomb', 'gotham city', 'vigilante', 'cover-up', 'superhero', 'villainess', 'tragic hero', 'terrorism', 'destruction', 'catwoman', 'cat burglar', 'imax', 'flood', 'criminal underworld', 'batman']
# ...

# %%
#print the df_
df_.head()
# Out:
#     index                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#Let's have a look into "cast" column
df_.loc[:, 'cast'][0]
#But, in that "cast" columns_ we will take only 3 dict with names:
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
#Do the same thing like previous
castList = []
for index_, values_ in enumerate(df_.loc[:, 'cast']):
    values_ = ast.literal_eval(values_)
    list_ = []
    for insideList_ in values_[0:3]:
        list_.append(insideList_['name'])
    castList.append(list_)
    print(list_)
df_.loc[:, 'cast'] = castList
print("Done !")
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']
# ['Johnny Depp', 'Orlando Bloom', 'Keira Knightley']
# ['Daniel Craig', 'Christoph Waltz', 'Léa Seydoux']
# ['Christian Bale', 'Michael Caine', 'Gary Oldman']
# ['Taylor Kitsch', 'Lynn Collins', 'Samantha Morton']
# ['Tobey Maguire', 'Kirsten Dunst', 'James Franco']
# ['Zachary Levi', 'Mandy Moore', 'Donna Murphy']
# ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo']
# ['Daniel Radcliffe', 'Rupert Grint', 'Emma Watson']
# ['Ben Affleck', 'Henry Cavill', 'Gal Gadot']
# ['Brandon Routh', 'Kevin Spacey', 'Kate Bosworth']
# ['Daniel Craig', 'Olga Kurylenko', 'Mathieu Amalric']
# ['Johnny Depp', 'Orlando Bloom', 'Keira Knightley']
# ['Johnny Depp', 'Armie Hammer', 'William Fichtner']
# ['Henry Cavill', 'Amy Adams', 'Michael Shannon']
# ['Ben Barnes', 'William Moseley', 'Anna Popplewell']
# ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo']
# ['Johnny Depp', 'Penélope Cruz', 'Ian McShane']
# ...

# %%
#print the df_
df_.head()
# Out:
#     index                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#Let's have a look into the crew columns
df_.loc[:, 'crew'][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
#In this "crew" section, we will exract those data which "job" = "Director" and save the "name" in that crew columns_
crewList_ = []
for values_ in df_.loc[:, 'crew']:
    values_ = ast.literal_eval(values_)
    list_ = []
    for insideList_ in values_:
        if insideList_['job'] == 'Director':
            list_.append(insideList_['name'])
            print(insideList_['name'])
        else:
            pass
    crewList_.append(list_)
df_.loc[:, 'crew'] = crewList_
# Out:
# James Cameron
# Gore Verbinski
# Sam Mendes
# Christopher Nolan
# Andrew Stanton
# Sam Raimi
# Byron Howard
# Nathan Greno
# Joss Whedon
# David Yates
# Zack Snyder
# Bryan Singer
# Marc Forster
# Gore Verbinski
# Gore Verbinski
# Zack Snyder
# Andrew Adamson
# Joss Whedon
# Rob Marshall
# Barry Sonnenfeld
# Peter Jackson
# Marc Webb
# Ridley Scott
# Peter Jackson
# Chris Weitz
# Peter Jackson
# James Cameron
# Anthony Russo
# Joe Russo
# Peter Berg
# Colin Trevorrow
# Sam Mendes
# Sam Raimi
# Shane Black
# Tim Burton
# Brett Ratner
# Dan Scanlon
# Michael Bay
# Michael Bay
# Sam Raimi
# Marc Webb
# Joseph Kosinski
# John Lasseter
# Brad Lewis
# Martin Campbell
# Lee Unkrich
# McG
# James Wan
# Marc Forster
# Bryan Singer
# J.J. Abrams
# Bryan Singer
# Baz Luhrmann
# Mike Newell
# Guillermo del Toro
# Michael Bay
# Steven Spielberg
# Peter Sohn
# Brenda Chapman
# Mark Andrews
# Steve Purcell
# Justin Lin
# Andrew Stanton
# Brett Ratner
# Roland Emmerich
# Robert Zemeckis
# ...

# %%
#print the df_
df_.head()
# Out:
#     index                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#  df_.loc[:, 'genres'].apply(lambda x: [values_.replace(" ","") for values_ in x])

# %%
#Create a remove space function:
def removeSpace(list_):
    return [values_.replace(" ","") for values_ in list_]

df_.loc[:, 'genres'] = df_.loc[:, 'genres'].apply(removeSpace)
print("Done !")
# Out:
# Done !

# %%
#print df_
df_.head()
# Out:
#     index                                        genres  \
# 0   19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1     285                  [Adventure, Fantasy, Action]
# 2  206647                    [Action, Adventure, Crime]
# 3   49026              [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#Do the same thing for "keywords", "cast", "crew" columns
df_.loc[:, 'keywords'] = df_.loc[:, 'keywords'].apply(removeSpace)
print("Done 1")
df_.loc[:, 'cast'] = df_.loc[:, 'cast'].apply(removeSpace)
print("Done 2")
df_.loc[:, 'crew'] = df_.loc[:, 'crew'].apply(removeSpace)
print("Done 3")
# Out:
# Done 1
# Done 2
# Done 3

# %%
#print df_
df_.head()
# Out:
#     index                                        genres  \
# 0   19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1     285                  [Adventure, Fantasy, Action]
# 2  206647                    [Action, Adventure, Crime]
# 3   49026              [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
#Now create another dataFrame_ with "genres", "keywords", "cast", "crew"
newDf_ = pd.concat([df_.loc[:, 'genres'],df_.loc[:, 'keywords'],df_.loc[:, 'cast'],df_.loc[:, 'crew']], axis = 1)
newDf_.head()
# Out:
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# ...

# %%
#Now, its the optimum time to made a list as a string. to do this, called ".join()"
newDf_.loc[:,:] = newDf_.applymap(lambda x: ' '.join(x))

# %%
#print the newDf_
newDf_
# Out:
#                                        genres  \
# 0     Action Adventure Fantasy ScienceFiction
# 1                    Adventure Fantasy Action
# 2                      Action Adventure Crime
# 3                 Action Crime Drama Thriller
# 4             Action Adventure ScienceFiction
# ...                                       ...
# 4798                    Action Crime Thriller
# 4799                           Comedy Romance
# 4800             Comedy Drama Romance TVMovie
# 4801
# 4802                              Documentary
#
#                                                keywords  \
# 0     cultureclash future spacewar spacecolony socie...
# 1     ocean drugabuse exoticisland eastindiatradingc...
# 2     spy basedonnovel secretagent sequel mi6 britis...
# 3     dccomics crimefighter terrorist secretidentity...
# 4     basedonnovel mars medallion spacetravel prince...
# ...                                                 ...
# ...

# %%
#I did set_option 
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 100)

# %%
newDf_.head()
# Out:
#                                     genres  \
# 0  Action Adventure Fantasy ScienceFiction
# 1                 Adventure Fantasy Action
# 2                   Action Adventure Crime
# 3              Action Crime Drama Thriller
# 4          Action Adventure ScienceFiction
#
#                                             keywords  \
# 0  cultureclash future spacewar spacecolony socie...
# 1  ocean drugabuse exoticisland eastindiatradingc...
# 2  spy basedonnovel secretagent sequel mi6 britis...
# 3  dccomics crimefighter terrorist secretidentity...
# 4  basedonnovel mars medallion spacetravel prince...
#
#                                         cast              crew
# 0  SamWorthington ZoeSaldana SigourneyWeaver      JamesCameron
# 1     JohnnyDepp OrlandoBloom KeiraKnightley     GoreVerbinski
# 2      DanielCraig ChristophWaltz LéaSeydoux         SamMendes
# 3      ChristianBale MichaelCaine GaryOldman  ChristopherNolan
# 4    TaylorKitsch LynnCollins SamanthaMorton     AndrewStanton

# %% [markdown]
# # Concatenate the rows with Overview columns

# %%
#Now, my task is to combine all the row 
columns_ = newDf_.columns
list_ = []
count_ = 0
def mergeDataset_(data_):
    global count_
    string_ = ""
    for values_ in columns_:
        string_ = string_ + newDf_.loc[count_, values_]+" "
        
    list_.append(df_.loc[count_, 'overview'] + string_)
    count_ = count_ + 1
    print("done ", count_)
    
print("completed !")
df_.loc[:, 'overview'].apply(mergeDataset_)
# Out:
# completed !
# done  1
# done  2
# done  3
# done  4
# done  5
# done  6
# done  7
# done  8
# done  9
# done  10
# done  11
# done  12
# done  13
# done  14
# done  15
# done  16
# done  17
# done  18
# done  19
# done  20
# done  21
# done  22
# done  23
# done  24
# done  25
# done  26
# done  27
# done  28
# done  29
# done  30
# done  31
# done  32
# done  33
# done  34
# done  35
# done  36
# done  37
# done  38
# done  39
# done  40
# done  41
# done  42
# done  43
# done  44
# done  45
# done  46
# done  47
# done  48
# done  49
# done  50
# done  51
# done  52
# done  53
# done  54
# done  55
# done  56
# done  57
# done  58
# done  59
# done  60
# done  61
# done  62
# done  63
# done  64
# done  65
# done  66
# done  67
# done  68
# done  69
# done  70
# done  71
# done  72
# done  73
# done  74
# done  75
# done  76
# done  77
# done  78
# done  79
# done  80
# done  81
# done  82
# done  83
# done  84
# done  85
# done  86
# done  87
# done  88
# done  89
# done  90
# ...

# %%
#print the list_
list_
# Out:
# ['In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron ',
#  "Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.Adventure Fantasy Action ocean drugabuse exoticisland eastindiatradingcompany loveofone'slife traitor shipwreck strongwoman ship alliance calypso afterlife fighter pirate swashbuckler aftercreditsstinger JohnnyDepp OrlandoBloom KeiraKnightley GoreVerbinski ",
# ...

# %%
#print the one element of list_
list_[1]
# Out:
# "Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.Adventure Fantasy Action ocean drugabuse exoticisland eastindiatradingcompany loveofone'slife traitor shipwreck strongwoman ship alliance calypso afterlife fighter pirate swashbuckler aftercreditsstinger JohnnyDepp OrlandoBloom KeiraKnightley GoreVerbinski "

# %%
#now print the df_
df_.head()
# Out:
#     index                                        genres  \
# 0   19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1     285                  [Adventure, Fantasy, Action]
# 2  206647                    [Action, Adventure, Crime]
# 3   49026              [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %% [markdown]
# # Dropped the columns

# %%
#delete the "genres","keywords","overview","cast","crew" columns
dropped_ = ["genres","keywords","overview","cast","crew"]

for values_ in dropped_:
    df_.drop(values_, axis = 1, inplace = True)
    print("Dropped ", values_)
    
print(" ")
print("Dropped completed.")
# Out:
# Dropped  genres
# Dropped  keywords
# Dropped  overview
# Dropped  cast
# Dropped  crew
#
# Dropped completed.

# %%
#print the df_
df_.head()
# Out:
#     index                                     title
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter

# %%
#Now, store the "list_" in that particular DataFrame
df_.loc[:, 'tags'] = list_
print("Done !")
# Out:
# Done !

# %%
#print the df_ with shape
print("The shape of data frame is: ", df_.shape,'\n')
df_.head()
# Out:
# The shape of data frame is:  (4803, 3)
#     index                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
#What we will have to do is "lower()" - in "tags" columns
df_.loc[:, 'tags'] = df_.loc[:, 'tags'].str.lower()
print("done !")
# Out:
# done !

# %%
#print df_ 
df_.head(5)
# Out:
#     index                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
#check one data whether it has been in lower or not !
check_ = df_.loc[:, 'tags'].str.islower()
if check_.all() == True:
    print("Yes, it transfomed as LOWER")
else:
    print("I am regret to say that it has been transformed as LOWER")
# Out:
# Yes, it transfomed as LOWER
